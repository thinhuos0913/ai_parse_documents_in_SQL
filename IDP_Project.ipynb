# %%
SELECT *
FROM read_files('/Volumes/idp/default/idp_project')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>modificationTime</th><th>length</th><th>content</th></tr></thead><tbody><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_10119.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>3141</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_23433.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>3141</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_16234.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>3133</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_34552.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>3128</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_48679.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>3124</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_93462.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>3023</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_61552.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>3012</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/purchase_order_keystone_25.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>2992</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/purchase_order_summit_25.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>2864</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/purchase_order_hawthorne_25.pdf</td><td>2026-03-07T05:35:14.000Z</td><td>2848</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_41151.pdf</td><td>2026-03-07T05:35:15.000Z</td><td>2340</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_226724.pdf</td><td>2026-03-07T05:35:15.000Z</td><td>2320</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_17924.pdf</td><td>2026-03-07T05:35:15.000Z</td><td>2291</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_523267.pdf</td><td>2026-03-07T05:35:15.000Z</td><td>2286</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_715673.pdf</td><td>2026-03-07T05:35:15.000Z</td><td>2286</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_30676.pdf</td><td>2026-03-07T05:35:15.000Z</td><td>2277</td><td>...</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_63355.pdf</td><td>2026-03-07T05:35:15.000Z</td><td>2253</td><td>...</td></tr></tbody></table></div>

# %%
CREATE OR REPLACE TABLE parsed_data AS
SELECT path,
ai_parse_document(content) as parsed_content
FROM read_files('/Volumes/idp/default/idp_project')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
SELECT *
FROM parsed_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>parsed_content</th></tr></thead><tbody><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_10119.pdf</td><td>{"document":{"elements":[{"bbox":[{"coord":[206,97,502,161],"page_id":0}],"content":"Riverbend Marketing Studio","description":null,"id":0,"type":"title"},{"bbox":[{"coord":[161,178,480,249],"page_id":0}],"content":"22 Kingfisher Ave\nNashville, TN 37203\n(615) 555-0172 • invoices@riverbendstudio.com\nWebsite: riverbendstudio.com","description":null,"id":1,"type":"text"},{"bbox":[{"coord":[652,100,774,125],"page_id":0}],"content":"INVOICE","description":null,"id":2,"type":"section_header"},{"bbox":[{"coord":[567,143,813,280],"page_id":0}],"content":"Invoice #: INV-20250010\nInvoice Date: 2025-01-17\nDue Date: 2025-01-17\nTerms: Due on Receipt\nPO #: PO-13352\nCurrency: USD\nPayment Method: Wire Transfer","description":null,"id":3,"type":"text"},{"bbox":[{"coord":[148,312,871,354],"page_id":0}],"content":"<table><tr><td>Bill To</td><td>Ship To</td></tr><tr><td></td><td></td></tr></table>","description":null,"id":4,"type":"table"},{"bbox":[{"coord":[161,367,1017,383],"page_id":0}],"content":"Keystone Logistics Partners<br>3400 River Rd<br>Harrisburg, PA 17110","description":null,"id":5,"type":"text"},{"bbox":[{"coord":[137,417,894,772],"page_id":0}],"content":"<table>\n  <tr><th>Description</th><th>Qty</th><th>Unit Price</th><th>Amount</th></tr><tr><td>Creative design (hours)</td><td>8</td><td>$93.48</td><td>$747.84</td></tr><tr><td>Ad spend management (hours)</td><td>12</td><td>$78.47</td><td>$941.64</td></tr><tr><td>Landing page build</td><td>1</td><td>$1,159.52</td><td>$1,159.52</td></tr><tr><td>Performance report</td><td>1</td><td>$385.23</td><td>$385.23</td></tr><tr><td>Campaign setup</td><td>1</td><td>$1,326.56</td><td>$1,326.56</td></tr><tr><td>Remit To: Riverbend Marketing Studio<br>PO Box 1903<br>Nashville, TN 37202</td><td>Subtotal</td><td></td><td>$4,560.79</td></tr><tr><td></td><td>Tax (0%)</td><td></td><td>$0.00</td></tr><tr><td></td><td>Total</td><td></td><td>$4,560.79</td></tr></table>","description":null,"id":6,"type":"table"},{"bbox":[{"coord":[93,793,722,807],"page_id":0}],"content":"Notes: Please include the invoice number with your payment. For questions, contact Accounts Receivable.","description":null,"id":7,"type":"text"}],"pages":[{"id":0,"image_uri":null}]},"error_status":null,"metadata":{"file_metadata":null,"id":"662e2d4a-f262-45ea-9723-84165ccfd4c8","version":"2.0"}}</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_16234.pdf</td><td>{"document":{"elements":[{"bbox":[{"coord":[170,99,538,124],"page_id":0}],"content":"Northstar IT Services LLC","description":null,"id":0,"type":"title"},{"bbox":[{"coord":[158,141,429,212],"page_id":0}],"content":"410 Market St, Suite 1200\nPhiladelphia, PA 19106\n(215) 555-0198 • billing@northstarit.com\nWebsite: northstarit.com","description":null,"id":1,"type":"text"},{"bbox":[{"coord":[652,100,775,124],"page_id":0}],"content":"INVOICE","description":null,"id":2,"type":"title"},{"bbox":[{"coord":[567,141,813,281],"page_id":0}],"content":"Invoice #: INV-20250001\nInvoice Date: 2025-01-01\nDue Date: 2025-01-01\nTerms: Due on Receipt\nPO #: PO-17238\nCurrency: USD\nPayment Method: Wire Transfer","description":null,"id":3,"type":"text"},{"bbox":[{"coord":[148,312,871,354],"page_id":0}],"content":"<table><tr><td>Bill To</td><td>Ship To</td></tr><tr><td></td><td></td></tr></table>","description":null,"id":4,"type":"table"},{"bbox":[{"coord":[158,367,1020,383],"page_id":0}],"content":"Pinecrest Manufacturing Inc.<br/>1200 Industrial Pkwy,Pinecrest,MI48640<br/>1200 Industrial Pkwy,Allentown, PA","description":null,"id":5,"type":"text"},{"bbox":[{"coord":[137,417,894,772],"page_id":0}],"content":"<table><tr><th>Description</th><th>Qty</th><th>Unit Price</th><th>Amount</th></tr><tr><td>Dashboard maintenance</td><td>10</td><td> ...

# %%
CREATE or REPLACE TABLE pretty_data AS
SELECT path,
concat_ws('\n',transform(try_cast(parsed_content:document:elements as array<variant>), e -> coalesce(try_cast(e:content as string), ''))) as doc_text
FROM parsed_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
CREATE OR REPLACE TABLE classified_data AS
SELECT *,
ai_classify(doc_text,ARRAY('Invoice','Purchase_Order','Receipt','Other')) as doc_classification
FROM pretty_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
CREATE OR REPLACE TABLE invoice_data AS
SELECT *,
ai_extract(doc_text,
ARRAY('Vendor_Name','Invoice_Number','Invoice_Date','Due_Date','Payment_Method','Total')) as extracted
FROM classified_data
WHERE doc_classification = 'Invoice'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
CREATE SCHEMA IF NOT EXISTS idp.finance
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
CREATE OR REPLACE TABLE idp.finance.invoices AS
SELECT path,
extracted.Vendor_Name AS Vendor,
extracted.Invoice_Number AS Invoice_Number,
extracted.Invoice_Date AS Invoice_Date,
extracted.Due_Date AS Due_Date,
extracted.Payment_Method AS Payment_Method,
extracted.Total AS Total
FROM invoice_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
SELECT *
FROM idp.finance.invoices
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>Vendor</th><th>Invoice_Number</th><th>Invoice_Date</th><th>Due_Date</th><th>Payment_Method</th><th>Total</th></tr></thead><tbody><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_10119.pdf</td><td>Riverbend Marketing Studio</td><td>INV-20250010</td><td>2025-01-17</td><td>2025-01-17</td><td>Wire Transfer</td><td>$4,560.79</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_16234.pdf</td><td>Northstar IT Services LLC</td><td>INV-20250001</td><td>2025-01-01</td><td>2025-01-01</td><td>Wire Transfer</td><td>$6,377.62</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_23433.pdf</td><td>Northstar IT Services LLC</td><td>INV-20250002</td><td>2025-01-15</td><td>2025-01-15</td><td>Wire Transfer</td><td>$7,406.66</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_34552.pdf</td><td>Northstar IT Services LLC</td><td>INV-20250003</td><td>2025-01-13</td><td>2025-02-12</td><td>Check</td><td>$7,842.98</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_48679.pdf</td><td>Northstar IT Services LLC</td><td>INV-20250004</td><td>2025-01-12</td><td>2025-02-11</td><td>ACH</td><td>$5,609.50</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_61552.pdf</td><td>Blue Ridge Office Supply Co.</td><td>INV-20250006</td><td>2025-01-25</td><td>2025-02-24</td><td>Check</td><td>$1,332.59</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/invoice_93462.pdf</td><td>Riverbend Marketing Studio</td><td>INV-20250009</td><td>2025-01-29</td><td>2025-01-29</td><td>Wire Transfer</td><td>$2,706.94</td></tr></tbody></table></div>

# %%
CREATE OR REPLACE TABLE purchase_order_data AS
SELECT *,
ai_extract(doc_text,
ARRAY('Merchant_Name','PO_Number','Invoice_Date','Purchase_Order_Date','Total')) as extracted
FROM classified_data
WHERE doc_classification = 'Purchase_Order'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
SELECT *
FROM purchase_order_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>doc_text</th><th>doc_classification</th><th>extracted</th></tr></thead><tbody><tr><td>dbfs:/Volumes/idp/default/idp_project/purchase_order_hawthorne_25.pdf</td><td>PURCHASE ORDER
# <table><tr><th>Buyer</th><th>Vendor</th></tr><tr><td>Hawthorne Hospitality Group<br>88 Westlake Blvd<br>Richmond, VA 23220</td><td>Riverbend Marketing Studio<br>Nashville, TN</td></tr></table>
# <table><tr><td>PO #</td><td>PO-24371</td><td>PO Date</td><td>2025-01-06</td></tr><tr><td>Requested Ship Date</td><td>2025-01-20</td><td>Currency</td><td>USD</td></tr></table>
# <table><tr><th>Line</th><th>Description</th><th>Qty</th><th>Unit Price</th><th>Amount</th></tr><tr><td>1</td><td>Creative package</td><td>1</td><td>$1,249.91</td><td>$1,249.91</td></tr><tr><td>2</td><td>Brochure printing</td><td>2</td><td>$1,190.47</td><td>$2,380.94</td></tr><tr><td>3</td><td>Onsite installation</td><td>3</td><td>$466.85</td><td>$1,400.55</td></tr><tr><td>4</td><td>Brochure printing</td><td>2</td><td>$68.49</td><td>$136.98</td></tr></table>
# <table><tr><td>Subtotal</td><td>$5,168.38</td></tr><tr><td>Shipping</td><td>$51.07</td></tr><tr><td>Total</td><td>$5,219.45</td></tr></table>
# Notes: Please reference the PO number on all invoices and packing slips.</td><td>Purchase_Order</td><td>List(Riverbend Marketing Studio, PO-24371, null, 2025-01-06, $5,219.45)</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/purchase_order_keystone_25.pdf</td><td>PURCHASE ORDER
# <table><tr><th>Buyer</th><th>Vendor</th></tr><tr><td>Keystone Logistics Partners<br>3400 River Rd<br>Hamsburg, PA 17110</td><td>Keystone Packaging Ltd.<br>Lancaster, PA</td></tr></table>
# <table><tr><td>PO #</td><td>PO-24564</td><td>PO Date</td><td>2025-01-28</td></tr><tr><td>Requested Ship Date</td><td>2025-02-01</td><td>Currency</td><td>USD</td></tr></table>
# <table><tr><th>Line</th><th>Description</th><th>Qty</th><th>Unit Price</th><th>Amount</th></tr><tr><td>1</td><td>Conference room supplies</td><td>10</td><td>$755.81</td><td>$7,558.10</td></tr><tr><td>2</td><td>Standing desk converter</td><td>3</td><td>$1,364.02</td><td>$4,092.06</td></tr><tr><td>3</td><td>Laptop docking station</td><td>3</td><td>$287.67</td><td>$863.01</td></tr><tr><td>4</td><td>Replacement parts kit</td><td>1</td><td>$188.39</td><td>$188.39</td></tr><tr><td>5</td><td>Creative package</td><td>3</td><td>$1,065.89</td><td>$3,197.67</td></tr><tr><td>6</td><td>Conference room supplies</td><td>4</td><td>$892.79</td><td>$3,571.16</td></tr></table>
# <table><tr><td>Subtotal</td><td>$19,470.39</td></tr><tr><td>Shipping</td><td>$94.04</td></tr><tr><td>Total</td><td>$19,564.43</td></tr></table>
# Notes: Please reference the PO number on all invoices and packing slips.</td><td>Purchase_Order</td><td>List(Keystone Packaging Ltd., PO-24564, null, 2025-01-28, $19,564.43)</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/purchase_order_summit_25.pdf</td><td>PURCHASE ORDER
# <table><tr><th>Buyer</th><th>Vendor</th></tr><tr><td>Summit Health Devices<br>950 MedTech Way<br>Princeton, NJ 08540</td><td>Blue Ridge Office Supply Co.<br>Roanoke, VA</td></tr></table>
# <table><tr><td>PO #</td><td>PO-29038</td><td>PO Date</td><td>2025-01-23</td></tr><tr><td>Requested Ship Date</td><td>2025-02-01</td><td>Currency</td><td>USD</td></tr></table>
# <table><tr><th>Line</th><th>Description</th><th>Qty</th><th>Unit Price</th><th>Amount</th></tr><tr><td>1</td><td>Laptop docking station</td><td>1</td><td>$1,372.25</td><td>$1,372.25</td></tr><tr><td>2</td><td>Monthly support retainer</td><td>5</td><td>$85.98</td><td>$429.90</td></tr><tr><td>3</td><td>Conference room supplies</td><td>5</td><td>$816.82</td><td>$4,084.10</td></tr><tr><td>4</td><td>Creative package</td><td>2</td><td>$94.19</td><td>$188.38</td></tr></table>
# <table><tr><td>Subtotal</td><td>$6,074.63</td></tr><tr><td>Shipping</td><td>$74.23</td></tr><tr><td>Total</td><td>$6,148.86</td></tr></table>
# Notes: Please reference the PO number on all invoices and packing slips.</td><td>Purchase_Order</td><td>List(Blue Ridge Office Supply Co., PO-29038, null, 2025-01-23, $6,148.86)</td></tr></tbody></table></div>

# %%
CREATE OR REPLACE TABLE idp.finance.purchase_orders AS
SELECT path,
extracted.Merchant_Name AS Merchant,
extracted.PO_Number AS Purchase_Order_Number,
extracted.Purchase_Order_Date AS Purchase_Order_Date,
extracted.Total AS Total
FROM purchase_order_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
SELECT *
FROM idp.finance.purchase_orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>Merchant</th><th>Purchase_Order_Number</th><th>Purchase_Order_Date</th><th>Total</th></tr></thead><tbody><tr><td>dbfs:/Volumes/idp/default/idp_project/purchase_order_hawthorne_25.pdf</td><td>Riverbend Marketing Studio</td><td>PO-24371</td><td>2025-01-06</td><td>$5,219.45</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/purchase_order_keystone_25.pdf</td><td>Keystone Packaging Ltd.</td><td>PO-24564</td><td>2025-01-28</td><td>$19,564.43</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/purchase_order_summit_25.pdf</td><td>Blue Ridge Office Supply Co.</td><td>PO-29038</td><td>2025-01-23</td><td>$6,148.86</td></tr></tbody></table></div>

# %%
CREATE OR REPLACE TABLE receipt_data AS
SELECT *,
ai_extract(doc_text,
ARRAY('Merchant_Name','Receipt_Number','Transaction_Date','Total', 'Payment_Method')) as extracted
FROM classified_data
WHERE doc_classification = 'Receipt'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
SELECT * 
FROM receipt_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>doc_text</th><th>doc_classification</th><th>extracted</th></tr></thead><tbody><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_17924.pdf</td><td>Green Leaf Grocers
# Philadelphia, PA
# Receipt #: R-842225
# Date/Time: 2025-01-08 08:04
# <table><tr><th>Item</th><th>Amount</th></tr><tr><td>Snack</td><td>$56.75</td></tr><tr><td>Service fee</td><td>$6.05</td></tr><tr><td>Fuel</td><td>$18.67</td></tr><tr><td>Hardware</td><td>$14.76</td></tr><tr><td>Office supplies</td><td>$45.69</td></tr><tr><td>Subtotal</td><td>$141.92</td></tr><tr><td>Tax</td><td>$9.93</td></tr><tr><td>Total</td><td>$151.85</td></tr></table>
# Payment Method: Visa **** 1964
# Return policy: Unopened items within 14 days with receipt. Thank you for your purchase.</td><td>Receipt</td><td>List(Green Leaf Grocers, R-842225, 2025-01-08, $151.85, Visa **** 1964)</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_226724.pdf</td><td>Metro Fuel Mart
# King of Prussia, PA
# Receipt #: R-922733
# Date/Time: 2025-01-19 15:15
# <table><tr><th>Item</th><th>Amount</th></tr><tr><td>Fuel</td><td>$7.48</td></tr><tr><td>Notebook</td><td>$27.94</td></tr><tr><td>Book</td><td>$26.72</td></tr><tr><td>USB cable</td><td>$5.04</td></tr><tr><td>Notebook</td><td>$61.54</td></tr><tr><td>Snack</td><td>$5.43</td></tr><tr><td>USB cable</td><td>$22.36</td></tr><tr><td>Subtotal</td><td>$156.51</td></tr><tr><td>Tax</td><td>$0.00</td></tr><tr><td>Total</td><td>$156.51</td></tr></table>
# Payment Method: Visa **** 8749
# Return policy: Unopened items within 14 days with receipt. Thank you for your purchase.</td><td>Receipt</td><td>List(Metro Fuel Mart, R-922733, 2025-01-19, $156.51, Visa **** 8749)</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_30676.pdf</td><td>Staple & Stone Cafe
# Phoenixville, PA
# Receipt #: R-662336
# Date/Time: 2025-01-08 11:12
# <table><tr><th>Item</th><th>Amount</th></tr><tr><td>Book</td><td>$12.90</td></tr><tr><td>Hardware</td><td>$16.93</td></tr><tr><td>Snack</td><td>$28.67</td></tr><tr><td>Meal</td><td>$7.70</td></tr><tr><td>Notebook</td><td>$62.46</td></tr><tr><td>Subtotal</td><td>$128.66</td></tr><tr><td>Tax</td><td>$0.00</td></tr><tr><td>Total</td><td>$128.66</td></tr></table>
# Payment Method: Visa **** 8350
# Return policy: Unopened items within 14 days with receipt. Thank you for your purchase.</td><td>Receipt</td><td>List(Staple & Stone Cafe, R-662336, 2025-01-08, $128.66, Visa **** 8350)</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_41151.pdf</td><td>Skyline Parking
# Philadelphia, PA
# Receipt #: R-347861
# Date/Time: 2025-01-03 20:54
# <table><tr><th>Item</th><th>Amount</th></tr><tr><td>Hardware</td><td>$30.99</td></tr><tr><td>Book</td><td>$56.57</td></tr><tr><td>Office supplies</td><td>$24.77</td></tr><tr><td>Book</td><td>$17.86</td></tr><tr><td>Shipping label</td><td>$49.45</td></tr><tr><td>Parking</td><td>$27.45</td></tr><tr><td>USB cable</td><td>$62.22</td></tr><tr><td>Subtotal</td><td>$269.31</td></tr><tr><td>Tax</td><td>$18.85</td></tr><tr><td>Total</td><td>$288.16</td></tr></table>
# Payment Method: Visa **** 3724
# Return policy: Unopened items within 14 days with receipt. Thank you for your purchase.</td><td>Receipt</td><td>List(Skyline Parking, R-347861, 2025-01-03, $288.16, Visa)</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_523267.pdf</td><td>Corner Hardware
# Exton, PA
# Receipt #: R-262316
# Date/Time: 2025-01-22 19:31
# <table><tr><th>Item</th><th>Amount</th></tr><tr><td>Fuel</td><td>$60.60</td></tr><tr><td>Ticket</td><td>$46.45</td></tr><tr><td>Beverage</td><td>$47.19</td></tr><tr><td>Beverage</td><td>$4.80</td></tr><tr><td>Hardware</td><td>$32.30</td></tr><tr><td>Meal</td><td>$11.31</td></tr><tr><td>Subtotal</td><td>$202.65</td></tr><tr><td>Tax</td><td>$14.19</td></tr><tr><td>Total</td><td>$216.84</td></tr></table>
# Payment Method: Visa **** 4111
# Return policy: Unopened items within 14 days with receipt. Thank you for your purchase.</td><td>Receipt</td><td>List(Corner Hardware, R-262316, 2025-01-22, $216.84, Visa)</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_63355.pdf</td><td>Transit Rail Ticketing
# Paoli, PA
# Receipt #: R-723939
# Date/Time: 2025-01-03 10:04
# <table><tr><th>Item</th><th>Amount</th></tr><tr><td>Book</td><td>$9.03</td></tr><tr><td>Ticket</td><td>$16.71</td></tr><tr><td>Ticket</td><td>$4.16</td></tr><tr><td>Snack</td><td>$27.22</td></tr><tr><td>Ticket</td><td>$36.09</td></tr><tr><td>Subtotal</td><td>$93.21</td></tr><tr><td>Tax</td><td>$5.59</td></tr><tr><td>Total</td><td>$98.80</td></tr></table>
# Payment Method: Visa **** 2113
# Return policy: Unopened items within 14 days with receipt. Thank you for your purchase.</td><td>Receipt</td><td>List(Transit Rail Ticketing, R-723939, 2025-01-03, $98.80, Visa **** 2113)</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_715673.pdf</td><td>Riverwalk Books
# West Chester, PA
# Receipt #: R-850981
# Date/Time: 2025-01-09 11:42
# <table><tr><th>Item</th><th>Amount</th></tr><tr><td>Parking</td><td>$25.79</td></tr><tr><td>Notebook</td><td>$40.96</td></tr><tr><td>Hardware</td><td>$20.96</td></tr><tr><td>Shipping label</td><td>$58.60</td></tr><tr><td>Beverage</td><td>$29.59</td></tr><tr><td>Subtotal</td><td>$175.90</td></tr><tr><td>Tax</td><td>$12.31</td></tr><tr><td>Total</td><td>$188.21</td></tr></table>
# Payment Method: Visa **** 6147
# Return policy: Unopened items within 14 days with receipt. Thank you for your purchase.</td><td>Receipt</td><td>List(Riverwalk Books, R-850981, 2025-01-09, $188.21, Visa **** 6147)</td></tr></tbody></table></div>

# %%
CREATE OR REPLACE TABLE idp.finance.receipts AS
SELECT path,
extracted.Merchant_Name AS Merchant,
extracted.Receipt_Number AS Receipt_Number,
extracted.Transaction_Date AS Transaction_Date,
extracted.Total AS Total,
extracted.Payment_Method AS Payment_Method
FROM receipt_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
SELECT *
FROM idp.finance.receipts
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>Merchant</th><th>Receipt_Number</th><th>Transaction_Date</th><th>Total</th><th>Payment_Method</th></tr></thead><tbody><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_17924.pdf</td><td>Green Leaf Grocers</td><td>R-842225</td><td>2025-01-08</td><td>$151.85</td><td>Visa **** 1964</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_226724.pdf</td><td>Metro Fuel Mart</td><td>R-922733</td><td>2025-01-19</td><td>$156.51</td><td>Visa **** 8749</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_30676.pdf</td><td>Staple & Stone Cafe</td><td>R-662336</td><td>2025-01-08</td><td>$128.66</td><td>Visa **** 8350</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_41151.pdf</td><td>Skyline Parking</td><td>R-347861</td><td>2025-01-03</td><td>$288.16</td><td>Visa</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_523267.pdf</td><td>Corner Hardware</td><td>R-262316</td><td>2025-01-22</td><td>$216.84</td><td>Visa</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_63355.pdf</td><td>Transit Rail Ticketing</td><td>R-723939</td><td>2025-01-03</td><td>$98.80</td><td>Visa **** 2113</td></tr><tr><td>dbfs:/Volumes/idp/default/idp_project/receipt_715673.pdf</td><td>Riverwalk Books</td><td>R-850981</td><td>2025-01-09</td><td>$188.21</td><td>Visa **** 6147</td></tr></tbody></table></div>
